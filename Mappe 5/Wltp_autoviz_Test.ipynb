# %%
import pandas as pd 
import numpy as np

data = pd.read_csv(r"C:\Users\erlen\Documents\sok-1005-v22\Mappe 5\wltp.csv", delimiter=";")
data
# Out:
#                    Bilmodell         Test  Rekkevidde i testen  Oppgitt WLTP  \
# 0             Audi e-tron 55  Sommer 2020                399.0           370
# 1   Audi e-tron 55 Sportback  Sommer 2020                436.0           376
# 2     Audi e-tron Quattro 50  Vinter 2020                259.0           332
# 3     Audi e-tron Quattro 55  Vinter 2020                341.0           415
# 4     Audi e-Tron GT quattro  Sommer 2021                528.1           468
# ..                       ...          ...                  ...           ...
# 83    Volvo XC40 Recharge P8  Sommer 2021                445.4           415
# 84    Volvo XC40 Recharge P8  Vinter 2021                332.0           409
# 85                  Xpeng G3  Sommer 2020                506.0           450
# 86                  Xpeng G3  Sommer 2021                438.9           451
# 87                  Xpeng G3  Vinter 2021                341.0           451
#
# ...

# %%
df =pd.DataFrame(data)
df
# Out:
#                    Bilmodell         Test  Rekkevidde i testen  Oppgitt WLTP  \
# 0             Audi e-tron 55  Sommer 2020                399.0           370
# 1   Audi e-tron 55 Sportback  Sommer 2020                436.0           376
# 2     Audi e-tron Quattro 50  Vinter 2020                259.0           332
# 3     Audi e-tron Quattro 55  Vinter 2020                341.0           415
# 4     Audi e-Tron GT quattro  Sommer 2021                528.1           468
# ..                       ...          ...                  ...           ...
# 83    Volvo XC40 Recharge P8  Sommer 2021                445.4           415
# 84    Volvo XC40 Recharge P8  Vinter 2021                332.0           409
# 85                  Xpeng G3  Sommer 2020                506.0           450
# 86                  Xpeng G3  Sommer 2021                438.9           451
# 87                  Xpeng G3  Vinter 2021                341.0           451
#
# ...

# %%
from autoviz.AutoViz_Class import AutoViz_Class
# %matplotlib inline

AV = AutoViz_Class()

viz = AV.AutoViz("wltp.csv", sep=";", depVar="Oppgitt WLTP")
viz
# Out:
# Shape of your Data Set loaded: (88, 8)
# #######################################################################################
# ######################## C L A S S I F Y I N G  V A R I A B L E S  ####################
# #######################################################################################
# Classifying variables in data set...
#     7 Predictors classified...
#         1 variables removed since they were ID or low-information variables
#
# ################ Regression problem #####################
# Number of All Scatter Plots = 3
# All Plots done
# Time to run AutoViz = 5 seconds
#
#  ###################### AUTO VISUALIZATION Completed ########################
#                    Bilmodell         Test  Rekkevidde i testen  \
# 0             Audi e-tron 55  Sommer 2020                399.0
# 1   Audi e-tron 55 Sportback  Sommer 2020                436.0
# 2     Audi e-tron Quattro 50  Vinter 2020                259.0
# ...

# %%
#test 
viz.plot_scatter()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/erlendsorra/git_repos/sok-1005-v22/Mappe 5/Wltp_autoviz_Test.ipynb Cell 4 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/Users/erlendsorra/git_repos/sok-1005-v22/Mappe%205/Wltp_autoviz_Test.ipynb#W3sZmlsZQ%3D%3D?line=0'>1</a> #test
# ----> <a href='vscode-notebook-cell:/Users/erlendsorra/git_repos/sok-1005-v22/Mappe%205/Wltp_autoviz_Test.ipynb#W3sZmlsZQ%3D%3D?line=1'>2</a> viz.plot_scatter()
#
# NameError: name 'viz' is not defined
